# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Path to the folder where you saved the model
save_folder = "./saved_model_codeT5_loaded"

# Load tokenizer and model from local folder
tokenizer = AutoTokenizer.from_pretrained(save_folder)
model = AutoModelForSequenceClassification.from_pretrained(save_folder)

# Set model to evaluation mode
model.eval()

print("Model and tokenizer loaded successfully!")
# Out:
# Model and tokenizer loaded successfully!

# %%
id2label = {0:"O(1)", 1:"O(n^3)", 2:"O(n)", 3:"O(2^n)", 4:"O(n^2)"}

# %%
# !pip install transformers datasets torch google-generativeai python-dotenv
# Out:
# Requirement already satisfied: transformers in c:\users\somri\miniconda3\lib\site-packages (4.56.0)
# Requirement already satisfied: datasets in c:\users\somri\miniconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: torch in c:\users\somri\miniconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: google-generativeai in c:\users\somri\miniconda3\lib\site-packages (0.8.5)
# Requirement already satisfied: python-dotenv in c:\users\somri\miniconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: filelock in c:\users\somri\miniconda3\lib\site-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\somri\miniconda3\lib\site-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\somri\miniconda3\lib\site-packages (from transformers) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\somri\miniconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\somri\miniconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\somri\miniconda3\lib\site-packages (from transformers) (2025.9.1)
# Requirement already satisfied: requests in c:\users\somri\miniconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\somri\miniconda3\lib\site-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\somri\miniconda3\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\somri\miniconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\somri\miniconda3\lib\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\somri\miniconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\somri\miniconda3\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in c:\users\somri\miniconda3\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\somri\miniconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in c:\users\somri\miniconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\somri\miniconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\somri\miniconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\somri\miniconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\somri\miniconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\somri\miniconda3\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\somri\miniconda3\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\somri\miniconda3\lib\site-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in c:\users\somri\miniconda3\lib\site-packages (from google-generativeai) (2.181.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\somri\miniconda3\lib\site-packages (from google-generativeai) (2.40.3)
# Requirement already satisfied: protobuf in c:\users\somri\miniconda3\lib\site-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in c:\users\somri\miniconda3\lib\site-packages (from google-generativeai) (2.10.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\somri\miniconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\somri\miniconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\somri\miniconda3\lib\site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\somri\miniconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\somri\miniconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\somri\miniconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\somri\miniconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\somri\miniconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\somri\miniconda3\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\somri\miniconda3\lib\site-packages (from requests->transformers) (2025.7.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\somri\miniconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\somri\miniconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\somri\miniconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.30.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\somri\miniconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\somri\miniconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\somri\miniconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\somri\miniconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\somri\miniconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\somri\miniconda3\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\somri\miniconda3\lib\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\somri\miniconda3\lib\site-packages (from pydantic->google-generativeai) (2.27.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\somri\miniconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\somri\miniconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\somri\miniconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\somri\miniconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\somri\miniconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\somri\miniconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\somri\miniconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\somri\miniconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\somri\miniconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in c:\users\somri\miniconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\somri\miniconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: six>=1.5 in c:\users\somri\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import torch
import google.generativeai as genai

# Directly pass your Gemini 2.5 Pro API key
import os

api_key = os.environ.get("GENIE_API_KEY")
genai.configure(api_key=api_key)

# Load the Gemini 2.5 Pro model
gemini_model = genai.GenerativeModel("gemini-2.5-pro")

# %%
import json

t5_model_path = "./saved_model_codeT5_loaded"
t5_tokenizer = AutoTokenizer.from_pretrained(t5_model_path)
t5_model = AutoModelForSequenceClassification.from_pretrained(t5_model_path)
t5_model.eval()
# Out:
# T5ForSequenceClassification(
#   (transformer): T5Model(
#     (shared): Embedding(32100, 512)
#     (encoder): T5Stack(
#       (embed_tokens): Embedding(32100, 512)
#       (block): ModuleList(
#         (0): T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#                 (relative_attention_bias): Embedding(32, 8)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (1-5): 5 x T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (final_layer_norm): T5LayerNorm()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (decoder): T5Stack(
#       (embed_tokens): Embedding(32100, 512)
#       (block): ModuleList(
#         (0): T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#                 (relative_attention_bias): Embedding(32, 8)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerCrossAttention(
#               (EncDecAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (2): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (1-5): 5 x T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerCrossAttention(
#               (EncDecAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (2): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (final_layer_norm): T5LayerNorm()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (classification_head): T5ClassificationHead(
#     (dense): Linear(in_features=512, out_features=512, bias=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#     (out_proj): Linear(in_features=512, out_features=5, bias=True)
#   )
# )

# %%
def predict_tc(code_snippet):
    inputs = t5_tokenizer(code_snippet, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        outputs = t5_model(**inputs)
    logits = outputs.logits
    pred_id = torch.argmax(logits, dim=-1).item()
    return id2label[pred_id]

# %%
import re

def analyze_with_gemini(code_snippet):
    prompt = f"""
Analyze this Python code and return three things:

1. Time Complexity (TC) in Big-O notation.
2. Space Complexity (SC) in Big-O notation.
3. One short suggestion to improve the code (if any).

Format EXACTLY like this:
TC: <time complexity>
SC: <space complexity>
Suggestion: <short suggestion>

{code_snippet}
"""
    try:
        response = gemini_model.generate_content(prompt)
        text = response.text.strip()

        # Extract TC, SC, Suggestion
        tc_match = re.search(r"TC:\s*(.*)", text)
        sc_match = re.search(r"SC:\s*(.*)", text)
        sg_match = re.search(r"Suggestion:\s*(.*)", text)

        result = {
            "tc": tc_match.group(1) if tc_match else "Unknown",
            "sc": sc_match.group(1) if sc_match else "Unknown",
            "suggestion": sg_match.group(1) if sg_match else "No suggestions"
        }

    except Exception as e:
        result = {"tc": "Unknown", "sc": "Unknown", "suggestion": "Analysis failed"}
    return result

# %%
def hybrid_analysis(code_snippet):
    # Step 1: T5 predicts TC
    tc_model = predict_tc(code_snippet)

    # Step 2: Gemini predicts TC & SC + Suggestion
    gemini_output = analyze_with_gemini(code_snippet)
    tc_gemini = gemini_output["tc"]
    sc_gemini = gemini_output["sc"]
    suggestion = gemini_output["suggestion"]

    # Step 3: Check mismatch
    mismatch_flag = (tc_model != tc_gemini)

    # Step 4: If mismatch, use Gemini's TC
    final_tc = tc_gemini if mismatch_flag else tc_model

    result = {
        "code": code_snippet,
        "tc_final": final_tc,
        "sc_gemini": sc_gemini,
        "suggestion": suggestion
    }

    return result

# %%
code_example = """
    def binary_search(arr, target):
    low, high = 0, len(arr)-1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return -1
"""

result = hybrid_analysis(code_example)
print(result)
# Out:
# {'code': '\n    def binary_search(arr, target):\n    low, high = 0, len(arr)-1\n    while low <= high:\n        mid = (low + high) // 2\n        if arr[mid] == target:\n            return mid\n        elif arr[mid] < target:\n            low = mid + 1\n        else:\n            high = mid - 1\n    return -1\n', 'tc_final': 'O(log n)', 'sc_gemini': 'O(1)', 'suggestion': 'Calculate mid as `low + (high - low) // 2` to prevent potential integer overflow on very large arrays.'}
